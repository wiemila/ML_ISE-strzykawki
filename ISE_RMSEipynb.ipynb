# %% [markdown]
# <a href="https://colab.research.google.com/github/wiemila/ML_ISE-strzykawki/blob/main/ISE_RMSEipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5cc53b36-925e-44ad-875a-f1d9f9e0c666" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5cc53b36-925e-44ad-875a-f1d9f9e0c666">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Dane pomidoryEJ3stezenia RMSE (2).csv']),delimiter=';')

# %%
df
# Out:
#                           Nazwa próbki  Kod  Rodzaj próbki  Powtórzenie  \
# 0                              Daktyle    1              1            1
# 1                              Daktyle    1              1            2
# 2                              Daktyle    1              1            3
# 3           barszcz diluted 45mlH2O5ml    2              2            1
# 4           barszcz diluted 45mlH2O5ml    2              2            2
# 5           barszcz diluted 45mlH2O5ml    2              2            3
# 6                     Tarczyn pikantny    3              3            1
# 7                     Tarczyn pikantny    3              3            2
# 8                     Tarczyn pikantny    3              3            3
# 9            tymbark klasyczny E190127    4              3            1
# 10           tymbark klasyczny E190127    4              3            2
# 11           tymbark klasyczny E190127    4              3            3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nazwa próbki    48 non-null     object
#  1   Kod             48 non-null     int64
#  2   Rodzaj próbki   48 non-null     int64
#  3   Powtórzenie     48 non-null     int64
#  4   Nazwa kodowana  48 non-null     object
#  5   DB5 steżenie    48 non-null     float64
#  6   DB4 stężenie    48 non-null     float64
#  7   V5 stezenie     48 non-null     float64
#  8   V5_2 stezenie   48 non-null     float64
#  9   V1_stezenie     48 non-null     float64
#  10  M               48 non-null     float64
# dtypes: float64(6), int64(3), object(2)
# memory usage: 4.2+ KB

# %%
#lets choose the all the columns except the concentration
Y_true = df.iloc[:,10].values

# %%
Y_true
# Out:
# array([0.05279042, 0.05279042, 0.05279042, 0.05115351, 0.05115351,
#        0.05115351, 0.06394189, 0.06394189, 0.06394189, 0.06394189,
#        0.06394189, 0.06394189, 0.06394189, 0.06394189, 0.06394189,
#        0.06394189, 0.06394189, 0.06394189, 0.06138421, 0.06138421,
#        0.06138421, 0.07673027, 0.07673027, 0.07673027, 0.03836513,
#        0.03836513, 0.03836513, 0.00019183, 0.00019183, 0.00019183,
#        0.00115863, 0.00115863, 0.00115863, 0.00017904, 0.00017904,
#        0.00017904, 0.01278838, 0.01278838, 0.01278838, 0.02532099,
#        0.02532099, 0.02532099, 0.06394189, 0.06394189, 0.06394189,
#        0.06394189, 0.06394189, 0.06394189])

# %%
# we will try to predict the concentration content so lets column concentration to y
yDB5 = df.iloc[:,5].values

# %%
# and check if its the concentration
print(yDB5)
# Out:
# [1.18488581 1.11957387 1.13970494 0.64267423 0.62072967 0.59160668
#  0.67789057 0.65893595 0.62364594 0.98608126 0.70060707 0.65210998
#  1.02889377 0.67609066 0.64152077 0.66126338 0.71276458 0.62868803
#  0.61133579 0.66826514 0.62972152 0.86495333 0.88108743 0.82755652
#  0.48024373 0.51007627 0.46984186 0.03951649 0.02985578 0.02681008
#  0.06533786 0.05779037 0.0535946  0.01172283 0.01413141 0.01489613
#  0.27468475 0.24176019 0.23728874 0.49106363 0.40677165 0.37895008
#  0.71506609 0.69398937 0.61183818 0.63925044 0.69076767 0.64998847]

# %%
print('MAE:', metrics.mean_absolute_error(Y_true, yDB5))
print('MSE:', metrics.mean_squared_error(Y_true, yDB5))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_true, yDB5)))
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# Out:
# MAE: 0.5025975476458333
# MSE: 0.3383392154146052
# RMSE: 0.5816693351162714

# %%
yDB4 = df.iloc[:,6].values
print('MAE:', metrics.mean_absolute_error(Y_true, yDB4))
print('MSE:', metrics.mean_squared_error(Y_true, yDB4))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_true, yDB4)))
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# Out:
# MAE: 0.2067228800208333
# MSE: 0.0726615448749544
# RMSE: 0.2695580547395206

# %%
yV5 = df.iloc[:,7].values
print('MAE:', metrics.mean_absolute_error(Y_true, yV5))
print('MSE:', metrics.mean_squared_error(Y_true, yV5))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_true, yV5)))
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# Out:
# MAE: 0.013742486208333335
# MSE: 0.0003016586074383846
# RMSE: 0.017368321952289593

# %%
yV5_2 = df.iloc[:,8].values
print('MAE:', metrics.mean_absolute_error(Y_true, yV5_2))
print('MSE:', metrics.mean_squared_error(Y_true, yV5_2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_true, yV5_2)))
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# Out:
# MAE: 0.3232562681458333
# MSE: 0.17371230625194092
# RMSE: 0.4167880831453089

# %%
yV3 = df.iloc[:,9].values
print('MAE:', metrics.mean_absolute_error(Y_true, yV3))
print('MSE:', metrics.mean_squared_error(Y_true, yV3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_true, yV3)))
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# Out:
# MAE: 0.024037835458333327
# MSE: 0.0010695444074118113
# RMSE: 0.03270388979023461
